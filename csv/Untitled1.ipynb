# %%
for(i=1;i<=n;i++,m+=2):
  if(m>9):
    m=1;
    
  for(j=1;j<=i;j++)
   printf("%d",m)
    
    
for i in range(1,9):
    i = i+2
    for j
# Out:
# 1
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19
# 2
# 6
# 8
# 10
# 12
# 14
# 16
# 18
# 20
# 3
# 7
# 9
# 11
# 13
# 15
# 17
# 19
# 21
# 4
# 8
# 10
# 12
# 14
# 16
# 18
# 20
# 22
# 5
# 9
# 11
# 13
# 15
# 17
# 19
# 21
# 23
# 6
# 10
# 12
# 14
# 16
# 18
# 20
# 22
# 24
# 7
# 11
# 13
# 15
# 17
# 19
# 21
# 23
# 25
# 8
# 12
# 14
# 16
# 18
# 20
# 22
# 24
# 26

# %%
for i in range(1, 8 + 1):
    for j in range(i, 0, -1):
        print(j)
        print("")
# Out:
# 1
#
# 2
#
# 1
#
# 3
#
# 2
#
# 1
#
# 4
#
# 3
#
# 2
#
# 1
#
# 5
#
# 4
#
# 3
#
# 2
#
# 1
#
# 6
#
# 5
#
# 4
#
# 3
#
# 2
#
# 1
#
# 7
#
# 6
#
# 5
#
# 4
#
# 3
#
# 2
#
# 1
#
# 8
#
# 7
#
# 6
#
# 5
#
# 4
#
# 3
#
# 2
#
# 1
